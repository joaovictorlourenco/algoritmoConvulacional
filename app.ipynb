# %% [markdown]
# Encontre um banco com 5 imagens imagens na web e modele uma Rede
# Neural Convolucional para fazer a classificação das imagens.

# %% [markdown]
# ### Etapa 1 – Convolução

# %%
import numpy as np
from PIL import Image
import os

def load_images(image_folder):
    images = []
    labelsFirst = []
    

    output_folder = 'imgsRedimensionadas'
    os.makedirs(output_folder, exist_ok=True) 
    print(f"Pasta '{output_folder}' criada ou já existe.")
    
    # Percorre cada pasta dentro da pasta de imagens
    for label in os.listdir(image_folder):
        label_folder = os.path.join(image_folder, label)
        
        # Verifica se é uma pasta
        if os.path.isdir(label_folder):  
            for file_name in os.listdir(label_folder):
                if file_name.endswith('.jpg'):
                    img_path = os.path.join(label_folder, file_name)
                    
                    # Tenta abrir e processar a imagem
                    try:
                        img = Image.open(img_path).convert('L')  # Converte para grayscale
                        img = img.resize((128, 128))  # Redimensiona para 128x128
                        
                        # Adiciona a imagem à lista
                        images.append(np.array(img))
                        labelsFirst.append(label)  # Usa o nome da pasta como label
                        
                        # Salva a imagem redimensionada na nova pasta
                        resized_img_path = os.path.join(output_folder, f"{label}_{file_name}")
                        img.save(resized_img_path)  # Salva a imagem redimensionada
                        
                        print(f"Imagem '{file_name}' redimensionada e salva em '{output_folder}' com label '{label}'.")

                    except Exception as e:
                        print(f"Erro ao processar a imagem '{file_name}': {e}")

    return np.array(images), np.array(labelsFirst)

# Substitua 'images_folder_path' pelo caminho da pasta onde estão as imagens
images, labelsFirst = load_images('imgs')

print(f"Total de imagens carregadas: {images.shape[0]}")
print("Labels associadas às imagens:", labelsFirst.shape)
# Out:
# Pasta 'imgsRedimensionadas' criada ou já existe.
# Imagem '4a291fe31f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '75fefe8441.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '4dacf9a3f0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '3c82e731e0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '9f23f879e5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '1aac205025.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '5c8e73a595.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '1d84834b1a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '2f3534e28e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '43b74457d1.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '2cb580feff.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '3eea4b31c6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '4f76a2f076.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '0e81eb0721.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '8d9950ed68.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '27f0f7f555.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '8ee3b0e5f5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '66ca05ab12.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '57ab95b826.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '9b05a25de1.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '26d834d229.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '27d28e5d8b.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '48fe954ed2.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '0c57e72045.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '5e67ac6642.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '7ff62f898d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '4f7dce13d9.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '8c2d171b9d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '40dc2cedec.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '16d29a1dc0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '0e757af2d5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '032ef781ef.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '8a24e8d62a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '24dd5cb3a6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '6c28066ea3.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '79fbd8424b.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '0ac6979eca.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '3c9d9b5adf.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '0f3f8d6a15.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '6faa7275fd.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '31c31736c6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '10ee8625c0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '4b0406eb70.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '23b99fb3bf.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '6d8a9a8f8f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '12b9c94601.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '70c11aab2e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '55ec112288.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '5b37e80a84.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '6d07c435dd.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '5f9155af55.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '4cccdaa27d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '3e526579ed.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '6ecfd5e88c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '2efd71c54e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '5edec096c0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '2c4dcd1d1e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '5d7d178594.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '72c584b509.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '18d2849164.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '82f3842d33.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '6dc58e2893.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '957c3736fc.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '4e071e5399.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '14a1eaf657.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '45af75e0da.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '0fa99039ab.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '759a9528e9.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '160cdad8e6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '2e3d7a7bd4.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '3d28692ff1.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '8af6a1eacd.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '8e2a1d91f8.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '0d562e4829.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '5ccea1aa7f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '9ade223a4d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '88ad9444d0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '462c97a5db.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '5f4eacc507.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '671f7ca8be.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '1a0fedad1a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '927d38205d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '2afadcf34f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '8e3037a963.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '10c5ebb8c4.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '43aebfb444.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '9e3c9b326e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '4583aa4975.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '517aca5da2.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '1111feb0ff.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '95c62debad.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '6da86c5015.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '3fbdf8c63c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '36e6bee909.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '357b607816.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '8c4b1f330a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '671dd289e7.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '55ca0c7f9c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '78c259940c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '5adc0a316b.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '5267f18ec9.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '7c3bc627c6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '6bf580fcf5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '5e5f10bcc4.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '0ec9efe6d8.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '60d72b6d7f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '797a3a9537.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '43c4bde0d3.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '5b2a142324.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '520c8528bc.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '603a820424.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '81c541cae0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '82e7b97984.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '47a87d7786.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '402ec9cd1b.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '771c3186af.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '2780aa6c10.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '1cb123c4e9.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '603c18f907.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '356ff70eab.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '00357563a7.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '8d88a86d91.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '9d21019336.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '2d7dc1ddb5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '1f016e1910.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '612c521481.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '8aefee4c2c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '39ae72da61.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '636b432421.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '0c3d04bcf5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '76273ddb00.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '72c56919f9.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '6a5e9eac29.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '5e07a0666d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '9293137b5d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '354bb2acdf.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '5aaea25f27.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '124eecb74f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '3321ec48a8.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '0d0d6d90d8.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '71c2375c64.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '66548aefad.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '6edc079fcf.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '46af339620.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '1a2dce7848.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '77dee19720.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '4bd8b7789f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '4815f8dfaa.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '31ae8d36b6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '6296ca5ccf.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '8af49688fa.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '78359cbe21.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '6fe978c917.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '3f3a2aaef2.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '11883c3dd8.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '6128bd1a84.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '4c6ff6dae0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '81b58d7d07.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '5a5cdbdc6b.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '68a2e3af59.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '7f923c6676.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '15b23c04b7.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '0cfaf08fce.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '98470f6918.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '9e020b77ac.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '34fb30ecc5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '029c926ce9.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '67dc417509.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '057e6db146.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '0b54dde5f5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '094ac674a9.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '2a40de8365.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '32cd00f171.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '578d493138.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '087d293433.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '730d6a8791.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '84db062d1f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '9fd544a838.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '71756f7bd0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '83e8a824a2.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '8c6a936c9a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '9efd18dd6c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '41f5881bb6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '63b74efb32.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '01c6b7230c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '4df813f7f1.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '2f0043ea55.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '36c2df0788.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '0be3797d3d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '26c7056eda.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '87bfbc889f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '7ca88b95e5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '084a6888d7.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '88dcdf1906.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '5c641a8bde.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '58b4804b9e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '7a42ed2c8d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '4ddebbca9a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '1d97824ca1.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '9aeb8c737b.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '0ff0ba075e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '9a8262798f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '3f956b8d4c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '22f99b4396.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '7a47b70b45.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '44a1bbc202.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '0b6670809d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '0d33157df8.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '76bad2abea.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '7c43d5ca9e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '5d961159a7.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '6afa462776.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '8deb324d92.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '2a8a6a6050.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '8edafffd38.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '05b151f72d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '4fdbeb98ad.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '024a037366.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '4aacd195b5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '1c768b0135.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '7b0c4e73fd.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '9bd48a19a4.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '62ebcbaf99.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '3fb7d7c4ef.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '23c5c07d8d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '6a5c5cce2c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '2afd300e67.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '4db9316411.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '2a74dd288c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '2cfd581819.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '9ac386dfb6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '7bee213463.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '82a669ccf6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '0a73823599.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '6be2081479.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '89af0e8454.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '17f6784a37.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '86ca756626.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '7f45bd0030.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '0df912089d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '64f159e8ff.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3f2fba956b.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '80f5e8d84a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '7d4b463567.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '82f107f486.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '098c4da6d0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '7e7669cc8a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '4c357a6907.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '68087b595a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '85ebd9b6f4.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '0bc9244dbf.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '23d5ae3c7f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '32eae3eecf.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '408bb4a1d3.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '8dc75d04ac.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '9640c80f78.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '7d42f0e881.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '6cccda21bb.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '369c4bfa7c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '7c1df0a13a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3846ac7fae.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '30e10509da.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '05768d38ec.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '987aa8b95e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '87fd3b8748.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3f5c04a48c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '88ce8d773f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3df89aa7cd.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '177bc31f99.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3e7a900953.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '2f714376e6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '6496eb14c0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '96decfc0ff.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '066fdf665a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '7e29f317b0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '9d5e9db945.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '491e05deef.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '46beba7077.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '17a29c13f5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '2defbeec7d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '9c8612ce65.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '361e677a43.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '7ea35b2c27.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '24df3def2d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '5d342f46d0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '2515fc48ed.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '95f848d627.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '8005f47721.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3d64a8f546.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '9bf76f7295.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '129dd77ad8.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '8e5ebe9684.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3a95b92996.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '1bdb6f9696.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3ecb859180.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '128fc39904.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '0dc9f0e83d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '4dd710bf1d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '928bda9343.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '8776f48a39.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Total de imagens carregadas: 300
# Labels associadas às imagens: (300,)

# %%
import numpy as np
from PIL import Image
import os

def convolve(image, kernel):
    h, w = image.shape
    kh, kw = kernel.shape
    output = np.zeros((h - kh + 1, w - kw + 1))

    print(f"Dimensões da imagem: {h}x{w}")
    print(f"Dimensões do kernel: {kh}x{kw}")

    for i in range(h - kh + 1):
        for j in range(w - kw + 1):
            region = image[i:i+kh, j:j+kw]
            output[i, j] = np.sum(region * kernel)

    return output

# Função para aplicar a convolução a todas as imagens e salvar os resultados
def apply_convolution_to_all_images(images, kernel, save_path):
    os.makedirs(save_path, exist_ok=True)
    convolved_images = []  # Lista para armazenar imagens convoluídas
    
    for idx, image in enumerate(images):
        # Aplica a convolução
        convolved_image = convolve(image, kernel)

        # Salvar a imagem convoluída
        output_image = Image.fromarray(convolved_image.astype(np.uint8))
        output_image.save(os.path.join(save_path, f'imagem_convoluida_{idx}.png'))  # Salva cada imagem com um nome único
        print(f"Imagem convoluída salva como: imagem_convoluida_{idx}.png")
        
        # Armazenar a imagem convoluída na lista
        convolved_images.append(convolved_image)

    return convolved_images  # Retornar a lista de imagens convoluídas

# Exemplo de kernel (filtro de detecção de bordas)
kernel = np.array([[0, -1, 0], 
                   [-1,  5, -1], 
                   [0, -1, 0]])

# Caminho para salvar as imagens finais da convolução
save_path = 'imgConvolucao'

# Carregar imagens da pasta especificada
images, _ = load_images('imgs')

# Aplicando convolução a todas as imagens e salvando as imagens finais
imagesConvolvidas = apply_convolution_to_all_images(images, kernel, save_path)

# Imprimindo as imagens convoluídas
print(imagesConvolvidas)
# Out:
# Pasta 'imgsRedimensionadas' criada ou já existe.
# Imagem '4a291fe31f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '75fefe8441.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '4dacf9a3f0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '3c82e731e0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '9f23f879e5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '1aac205025.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '5c8e73a595.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '1d84834b1a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '2f3534e28e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '43b74457d1.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '2cb580feff.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '3eea4b31c6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '4f76a2f076.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '0e81eb0721.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '8d9950ed68.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '27f0f7f555.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '8ee3b0e5f5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '66ca05ab12.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '57ab95b826.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '9b05a25de1.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '26d834d229.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '27d28e5d8b.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '48fe954ed2.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '0c57e72045.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '5e67ac6642.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '7ff62f898d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '4f7dce13d9.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '8c2d171b9d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '40dc2cedec.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '16d29a1dc0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '0e757af2d5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '032ef781ef.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '8a24e8d62a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '24dd5cb3a6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '6c28066ea3.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '79fbd8424b.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '0ac6979eca.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '3c9d9b5adf.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '0f3f8d6a15.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '6faa7275fd.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '31c31736c6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '10ee8625c0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '4b0406eb70.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '23b99fb3bf.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '6d8a9a8f8f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '12b9c94601.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '70c11aab2e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '55ec112288.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '5b37e80a84.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '6d07c435dd.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '5f9155af55.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '4cccdaa27d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '3e526579ed.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '6ecfd5e88c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '2efd71c54e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '5edec096c0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '2c4dcd1d1e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '5d7d178594.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '72c584b509.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '18d2849164.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'elephant'.
# Imagem '82f3842d33.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '6dc58e2893.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '957c3736fc.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '4e071e5399.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '14a1eaf657.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '45af75e0da.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '0fa99039ab.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '759a9528e9.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '160cdad8e6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '2e3d7a7bd4.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '3d28692ff1.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '8af6a1eacd.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '8e2a1d91f8.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '0d562e4829.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '5ccea1aa7f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '9ade223a4d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '88ad9444d0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '462c97a5db.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '5f4eacc507.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '671f7ca8be.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '1a0fedad1a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '927d38205d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '2afadcf34f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '8e3037a963.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '10c5ebb8c4.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '43aebfb444.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '9e3c9b326e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '4583aa4975.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '517aca5da2.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '1111feb0ff.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '95c62debad.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '6da86c5015.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '3fbdf8c63c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '36e6bee909.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '357b607816.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '8c4b1f330a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '671dd289e7.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '55ca0c7f9c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '78c259940c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '5adc0a316b.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '5267f18ec9.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '7c3bc627c6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '6bf580fcf5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '5e5f10bcc4.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '0ec9efe6d8.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '60d72b6d7f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '797a3a9537.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '43c4bde0d3.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '5b2a142324.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '520c8528bc.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '603a820424.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '81c541cae0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '82e7b97984.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '47a87d7786.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '402ec9cd1b.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '771c3186af.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '2780aa6c10.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '1cb123c4e9.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '603c18f907.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '356ff70eab.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'bee'.
# Imagem '00357563a7.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '8d88a86d91.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '9d21019336.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '2d7dc1ddb5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '1f016e1910.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '612c521481.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '8aefee4c2c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '39ae72da61.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '636b432421.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '0c3d04bcf5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '76273ddb00.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '72c56919f9.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '6a5e9eac29.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '5e07a0666d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '9293137b5d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '354bb2acdf.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '5aaea25f27.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '124eecb74f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '3321ec48a8.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '0d0d6d90d8.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '71c2375c64.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '66548aefad.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '6edc079fcf.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '46af339620.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '1a2dce7848.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '77dee19720.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '4bd8b7789f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '4815f8dfaa.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '31ae8d36b6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '6296ca5ccf.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '8af49688fa.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '78359cbe21.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '6fe978c917.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '3f3a2aaef2.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '11883c3dd8.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '6128bd1a84.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '4c6ff6dae0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '81b58d7d07.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '5a5cdbdc6b.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '68a2e3af59.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '7f923c6676.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '15b23c04b7.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '0cfaf08fce.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '98470f6918.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '9e020b77ac.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '34fb30ecc5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '029c926ce9.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '67dc417509.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '057e6db146.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '0b54dde5f5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '094ac674a9.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '2a40de8365.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '32cd00f171.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '578d493138.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '087d293433.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '730d6a8791.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '84db062d1f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '9fd544a838.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '71756f7bd0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '83e8a824a2.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cat'.
# Imagem '8c6a936c9a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '9efd18dd6c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '41f5881bb6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '63b74efb32.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '01c6b7230c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '4df813f7f1.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '2f0043ea55.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '36c2df0788.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '0be3797d3d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '26c7056eda.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '87bfbc889f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '7ca88b95e5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '084a6888d7.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '88dcdf1906.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '5c641a8bde.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '58b4804b9e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '7a42ed2c8d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '4ddebbca9a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '1d97824ca1.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '9aeb8c737b.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '0ff0ba075e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '9a8262798f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '3f956b8d4c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '22f99b4396.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '7a47b70b45.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '44a1bbc202.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '0b6670809d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '0d33157df8.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '76bad2abea.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '7c43d5ca9e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '5d961159a7.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '6afa462776.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '8deb324d92.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '2a8a6a6050.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '8edafffd38.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '05b151f72d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '4fdbeb98ad.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '024a037366.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '4aacd195b5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '1c768b0135.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '7b0c4e73fd.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '9bd48a19a4.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '62ebcbaf99.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '3fb7d7c4ef.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '23c5c07d8d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '6a5c5cce2c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '2afd300e67.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '4db9316411.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '2a74dd288c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '2cfd581819.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '9ac386dfb6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '7bee213463.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '82a669ccf6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '0a73823599.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '6be2081479.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '89af0e8454.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '17f6784a37.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '86ca756626.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '7f45bd0030.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '0df912089d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'dog'.
# Imagem '64f159e8ff.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3f2fba956b.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '80f5e8d84a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '7d4b463567.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '82f107f486.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '098c4da6d0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '7e7669cc8a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '4c357a6907.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '68087b595a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '85ebd9b6f4.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '0bc9244dbf.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '23d5ae3c7f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '32eae3eecf.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '408bb4a1d3.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '8dc75d04ac.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '9640c80f78.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '7d42f0e881.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '6cccda21bb.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '369c4bfa7c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '7c1df0a13a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3846ac7fae.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '30e10509da.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '05768d38ec.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '987aa8b95e.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '87fd3b8748.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3f5c04a48c.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '88ce8d773f.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3df89aa7cd.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '177bc31f99.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3e7a900953.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '2f714376e6.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '6496eb14c0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '96decfc0ff.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '066fdf665a.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '7e29f317b0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '9d5e9db945.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '491e05deef.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '46beba7077.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '17a29c13f5.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '2defbeec7d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '9c8612ce65.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '361e677a43.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '7ea35b2c27.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '24df3def2d.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '5d342f46d0.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '2515fc48ed.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '95f848d627.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '8005f47721.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3d64a8f546.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '9bf76f7295.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '129dd77ad8.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '8e5ebe9684.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3a95b92996.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '1bdb6f9696.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '3ecb859180.jpg' redimensionada e salva em 'imgsRedimensionadas' com label 'cow'.
# Imagem '128fc39904.jpg' redimensionada e salva em 'imgsRedimensionadas' com label '
#        [250., 251., 241., ..., 167., 188., 166.]]), array([[127., 134., 126., ..., 103.,  99.,  94.],
#        [124., 129., 132., ..., 105., 103.,  93.],
#        [122., 126., 133., ..., 103., 101.,  93.],
#        ...,
#        [ 13.,  61.,  72., ..., 171., 153.,  43.],
#        [ 19.,  53.,  82., ..., 138.,  76.,  34.],
#        [ 40.,  43.,  88., ..., 102.,  21.,  31.]]), array([[214., 214., 213., ..., 227., 224., 228.],
#        [213., 213., 212., ..., 226., 224., 220.],
#        [211., 211., 210., ..., 218., 216., 218.],
#        ...,
#        [234., 230., 242., ..., 237., 237., 237.],
#        [228., 219., 236., ..., 240., 240., 240.],
#        [256., 263., 251., ..., 243., 246., 247.]])]

# %% [markdown]
# ### Etapa 2 – Pooling

# %%
import numpy as np
import os
from PIL import Image

def max_pooling(image, pool_size):
    h, w = image.shape
    ph, pw = pool_size
    output_height = h // ph
    output_width = w // pw
    output = np.zeros((output_height, output_width))
    
    for i in range(output_height):
        for j in range(output_width):
            region = image[i * ph:(i + 1) * ph, j * pw:(j + 1) * pw]
            output[i, j] = np.max(region)
    
    return output

def apply_max_pooling_to_all_images(convolved_images, pool_size, save_path):
    os.makedirs(save_path, exist_ok=True)  # Criar a pasta para salvar as imagens, se não existir
    pooled_images = []  # Lista para armazenar as imagens resultantes do pooling

    for idx, image in enumerate(convolved_images):
        # Verifica se a imagem é 2D
        if len(image.shape) != 2:
            print(f"Imagem {idx} não é 2D. Ignorando...")
            continue
        
        pooled_image = max_pooling(image, pool_size)
        
        # Salvar a imagem final do pooling
        output_image = Image.fromarray(pooled_image.astype(np.uint8))
        output_image.save(os.path.join(save_path, f'imagem_pooled_{idx}.png'))  # Salva cada imagem com um nome único
        print(f"Imagem com pooling salva como: imagem_pooled_{idx}.png")
        
        pooled_images.append(pooled_image)  # Adiciona a imagem resultante à lista

        # Verifique a forma da imagem após o pooling
        print(f"Imagem {idx} após pooling: {pooled_image.shape}")

    return pooled_images  # Retorna a lista de imagens resultantes

# Defina o caminho para salvar as imagens de pooling
pooling_save_path = 'imgPooling'

# Aplicar max pooling a todas as imagens convoluídas
# Assegure-se de que as imagens convoluídas foram geradas anteriormente
pooled_images = apply_max_pooling_to_all_images(imagesConvolvidas, (2, 2), pooling_save_path)

# Imprimindo o total de imagens após pooling
print(f"Total de imagens após pooling: {len(pooled_images)}")
# Out:
# Imagem com pooling salva como: imagem_pooled_0.png
# Imagem 0 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_1.png
# Imagem 1 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_2.png
# Imagem 2 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_3.png
# Imagem 3 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_4.png
# Imagem 4 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_5.png
# Imagem 5 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_6.png
# Imagem 6 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_7.png
# Imagem 7 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_8.png
# Imagem 8 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_9.png
# Imagem 9 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_10.png
# Imagem 10 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_11.png
# Imagem 11 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_12.png
# Imagem 12 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_13.png
# Imagem 13 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_14.png
# Imagem 14 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_15.png
# Imagem 15 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_16.png
# Imagem 16 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_17.png
# Imagem 17 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_18.png
# Imagem 18 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_19.png
# Imagem 19 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_20.png
# Imagem 20 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_21.png
# Imagem 21 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_22.png
# Imagem 22 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_23.png
# Imagem 23 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_24.png
# Imagem 24 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_25.png
# Imagem 25 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_26.png
# Imagem 26 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_27.png
# Imagem 27 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_28.png
# Imagem 28 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_29.png
# Imagem 29 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_30.png
# Imagem 30 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_31.png
# Imagem 31 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_32.png
# Imagem 32 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_33.png
# Imagem 33 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_34.png
# Imagem 34 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_35.png
# Imagem 35 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_36.png
# Imagem 36 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_37.png
# Imagem 37 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_38.png
# Imagem 38 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_39.png
# Imagem 39 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_40.png
# Imagem 40 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_41.png
# Imagem 41 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_42.png
# Imagem 42 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_43.png
# Imagem 43 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_44.png
# Imagem 44 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_45.png
# Imagem 45 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_46.png
# Imagem 46 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_47.png
# Imagem 47 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_48.png
# Imagem 48 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_49.png
# Imagem 49 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_50.png
# Imagem 50 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_51.png
# Imagem 51 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_52.png
# Imagem 52 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_53.png
# Imagem 53 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_54.png
# Imagem 54 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_55.png
# Imagem 55 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_56.png
# Imagem 56 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_57.png
# Imagem 57 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_58.png
# Imagem 58 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_59.png
# Imagem 59 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_60.png
# Imagem 60 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_61.png
# Imagem 61 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_62.png
# Imagem 62 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_63.png
# Imagem 63 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_64.png
# Imagem 64 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_65.png
# Imagem 65 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_66.png
# Imagem 66 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_67.png
# Imagem 67 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_68.png
# Imagem 68 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_69.png
# Imagem 69 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_70.png
# Imagem 70 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_71.png
# Imagem 71 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_72.png
# Imagem 72 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_73.png
# Imagem 73 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_74.png
# Imagem 74 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_75.png
# Imagem 75 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_76.png
# Imagem 76 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_77.png
# Imagem 77 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_78.png
# Imagem 78 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_79.png
# Imagem 79 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_80.png
# Imagem 80 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_81.png
# Imagem 81 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_82.png
# Imagem 82 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_83.png
# Imagem 83 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_84.png
# Imagem 84 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_85.png
# Imagem 85 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_86.png
# Imagem 86 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_87.png
# Imagem 87 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_88.png
# Imagem 88 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_89.png
# Imagem 89 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_90.png
# Imagem 90 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_91.png
# Imagem 91 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_92.png
# Imagem 92 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_93.png
# Imagem 93 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_94.png
# Imagem 94 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_95.png
# Imagem 95 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_96.png
# Imagem 96 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_97.png
# Imagem 97 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_98.png
# Imagem 98 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_99.png
# Imagem 99 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_100.png
# Imagem 100 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_101.png
# Imagem 101 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_102.png
# Imagem 102 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_103.png
# Imagem 103 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_104.png
# Imagem 104 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_105.png
# Imagem 105 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_106.png
# Imagem 106 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_107.png
# Imagem 107 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_108.png
# Imagem 108 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_109.png
# Imagem 109 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_110.png
# Imagem 110 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_111.png
# Imagem 111 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_112.png
# Imagem 112 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_113.png
# Imagem 113 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_114.png
# Imagem 114 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_115.png
# Imagem 115 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_116.png
# Imagem 116 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_117.png
# Imagem 117 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_118.png
# Imagem 118 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_119.png
# Imagem 119 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_120.png
# Imagem 120 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_121.png
# Imagem 121 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_122.png
# Imagem 122 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_123.png
# Imagem 123 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_124.png
# Imagem 124 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_125.png
# Imagem 125 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_126.png
# Imagem 126 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_127.png
# Imagem 127 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_128.png
# Imagem 128 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_129.png
# Imagem 129 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_130.png
# Imagem 130 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_131.png
# Imagem 131 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_132.png
# Imagem 132 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_133.png
# Imagem 133 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_134.png
# Imagem 134 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_135.png
# Imagem 135 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_136.png
# Imagem 136 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_137.png
# Imagem 137 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_138.png
# Imagem 138 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_139.png
# Imagem 139 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_140.png
# Imagem 140 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_141.png
# Imagem 141 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_142.png
# Imagem 142 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_143.png
# Imagem 143 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_144.png
# Imagem 144 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_145.png
# Imagem 145 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_146.png
# Imagem 146 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_147.png
# Imagem 147 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_148.png
# Imagem 148 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_149.png
# Imagem 149 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_150.png
# Imagem 150 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_151.png
# Imagem 151 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_152.png
# Imagem 152 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_153.png
# Imagem 153 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_154.png
# Imagem 154 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_155.png
# Imagem 155 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_156.png
# Imagem 156 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_157.png
# Imagem 157 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_158.png
# Imagem 158 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_159.png
# Imagem 159 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_160.png
# Imagem 160 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_161.png
# Imagem 161 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_162.png
# Imagem 162 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_163.png
# Imagem 163 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_164.png
# Imagem 164 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_165.png
# Imagem 165 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_166.png
# Imagem 166 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_167.png
# Imagem 167 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_168.png
# Imagem 168 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_169.png
# Imagem 169 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_170.png
# Imagem 170 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_171.png
# Imagem 171 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_172.png
# Imagem 172 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_173.png
# Imagem 173 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_174.png
# Imagem 174 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_175.png
# Imagem 175 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_176.png
# Imagem 176 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_177.png
# Imagem 177 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_178.png
# Imagem 178 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_179.png
# Imagem 179 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_180.png
# Imagem 180 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_181.png
# Imagem 181 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_182.png
# Imagem 182 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_183.png
# Imagem 183 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_184.png
# Imagem 184 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_185.png
# Imagem 185 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_186.png
# Imagem 186 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_187.png
# Imagem 187 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_188.png
# Imagem 188 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_189.png
# Imagem 189 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_190.png
# Imagem 190 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_191.png
# Imagem 191 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_192.png
# Imagem 192 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_193.png
# Imagem 193 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_194.png
# Imagem 194 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_195.png
# Imagem 195 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_196.png
# Imagem 196 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_197.png
# Imagem 197 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_198.png
# Imagem 198 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_199.png
# Imagem 199 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_200.png
# Imagem 200 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_201.png
# Imagem 201 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_202.png
# Imagem 202 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_203.png
# Imagem 203 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_204.png
# Imagem 204 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_205.png
# Imagem 205 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_206.png
# Imagem 206 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_207.png
# Imagem 207 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_208.png
# Imagem 208 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_209.png
# Imagem 209 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_210.png
# Imagem 210 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_211.png
# Imagem 211 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_212.png
# Imagem 212 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_213.png
# Imagem 213 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_214.png
# Imagem 214 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_215.png
# Imagem 215 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_216.png
# Imagem 216 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_217.png
# Imagem 217 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_218.png
# Imagem 218 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_219.png
# Imagem 219 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_220.png
# Imagem 220 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_221.png
# Imagem 221 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_222.png
# Imagem 222 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_223.png
# Imagem 223 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_224.png
# Imagem 224 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_225.png
# Imagem 225 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_226.png
# Imagem 226 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_227.png
# Imagem 227 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_228.png
# Imagem 228 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_229.png
# Imagem 229 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_230.png
# Imagem 230 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_231.png
# Imagem 231 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_232.png
# Imagem 232 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_233.png
# Imagem 233 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_234.png
# Imagem 234 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_235.png
# Imagem 235 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_236.png
# Imagem 236 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_237.png
# Imagem 237 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_238.png
# Imagem 238 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_239.png
# Imagem 239 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_240.png
# Imagem 240 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_241.png
# Imagem 241 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_242.png
# Imagem 242 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_243.png
# Imagem 243 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_244.png
# Imagem 244 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_245.png
# Imagem 245 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_246.png
# Imagem 246 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_247.png
# Imagem 247 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_248.png
# Imagem 248 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_249.png
# Imagem 249 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_250.png
# Imagem 250 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_251.png
# Imagem 251 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_252.png
# Imagem 252 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_253.png
# Imagem 253 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_254.png
# Imagem 254 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_255.png
# Imagem 255 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_256.png
# Imagem 256 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_257.png
# Imagem 257 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_258.png
# Imagem 258 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_259.png
# Imagem 259 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_260.png
# Imagem 260 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_261.png
# Imagem 261 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_262.png
# Imagem 262 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_263.png
# Imagem 263 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_264.png
# Imagem 264 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_265.png
# Imagem 265 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_266.png
# Imagem 266 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_267.png
# Imagem 267 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_268.png
# Imagem 268 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_269.png
# Imagem 269 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_270.png
# Imagem 270 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_271.png
# Imagem 271 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_272.png
# Imagem 272 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_273.png
# Imagem 273 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_274.png
# Imagem 274 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_275.png
# Imagem 275 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_276.png
# Imagem 276 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_277.png
# Imagem 277 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_278.png
# Imagem 278 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_279.png
# Imagem 279 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_280.png
# Imagem 280 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_281.png
# Imagem 281 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_282.png
# Imagem 282 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_283.png
# Imagem 283 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_284.png
# Imagem 284 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_285.png
# Imagem 285 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_286.png
# Imagem 286 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_287.png
# Imagem 287 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_288.png
# Imagem 288 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_289.png
# Imagem 289 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_290.png
# Imagem 290 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_291.png
# Imagem 291 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_292.png
# Imagem 292 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_293.png
# Imagem 293 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_294.png
# Imagem 294 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_295.png
# Imagem 295 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_296.png
# Imagem 296 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_297.png
# Imagem 297 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_298.png
# Imagem 298 após pooling: (63, 63)
# Imagem com pooling salva como: imagem_pooled_299.png
# Imagem 299 após pooling: (63, 63)
# Total de imagens após pooling: 300

# %% [markdown]
# ### Etapa 3 – Flattening

# %%
def flatten(image):
    return image.flatten()  # Achata a matriz 2D em um vetor 1D

def apply_flattening_to_all_images(pooled_images):
    flattened_images = []  # Lista para armazenar imagens achatadas
    
    for idx, image in enumerate(pooled_images):
        # Achata a imagem e adiciona à lista
        flattened_image = flatten(image)
        flattened_images.append(flattened_image)
        print(f"Imagem {idx} achatada: {flattened_image.shape}")

    return flattened_images  # Retorna a lista de imagens achatadas

# Aplicar flattening a todas as imagens após pooling
flattened_images = apply_flattening_to_all_images(pooled_images)

# Imprimindo o total de imagens achatadas
print(f"Total de imagens achatadas: {len(flattened_images)}")
# Out:
# Imagem 0 achatada: (3969,)
# Imagem 1 achatada: (3969,)
# Imagem 2 achatada: (3969,)
# Imagem 3 achatada: (3969,)
# Imagem 4 achatada: (3969,)
# Imagem 5 achatada: (3969,)
# Imagem 6 achatada: (3969,)
# Imagem 7 achatada: (3969,)
# Imagem 8 achatada: (3969,)
# Imagem 9 achatada: (3969,)
# Imagem 10 achatada: (3969,)
# Imagem 11 achatada: (3969,)
# Imagem 12 achatada: (3969,)
# Imagem 13 achatada: (3969,)
# Imagem 14 achatada: (3969,)
# Imagem 15 achatada: (3969,)
# Imagem 16 achatada: (3969,)
# Imagem 17 achatada: (3969,)
# Imagem 18 achatada: (3969,)
# Imagem 19 achatada: (3969,)
# Imagem 20 achatada: (3969,)
# Imagem 21 achatada: (3969,)
# Imagem 22 achatada: (3969,)
# Imagem 23 achatada: (3969,)
# Imagem 24 achatada: (3969,)
# Imagem 25 achatada: (3969,)
# Imagem 26 achatada: (3969,)
# Imagem 27 achatada: (3969,)
# Imagem 28 achatada: (3969,)
# Imagem 29 achatada: (3969,)
# Imagem 30 achatada: (3969,)
# Imagem 31 achatada: (3969,)
# Imagem 32 achatada: (3969,)
# Imagem 33 achatada: (3969,)
# Imagem 34 achatada: (3969,)
# Imagem 35 achatada: (3969,)
# Imagem 36 achatada: (3969,)
# Imagem 37 achatada: (3969,)
# Imagem 38 achatada: (3969,)
# Imagem 39 achatada: (3969,)
# Imagem 40 achatada: (3969,)
# Imagem 41 achatada: (3969,)
# Imagem 42 achatada: (3969,)
# Imagem 43 achatada: (3969,)
# Imagem 44 achatada: (3969,)
# Imagem 45 achatada: (3969,)
# Imagem 46 achatada: (3969,)
# Imagem 47 achatada: (3969,)
# Imagem 48 achatada: (3969,)
# Imagem 49 achatada: (3969,)
# Imagem 50 achatada: (3969,)
# Imagem 51 achatada: (3969,)
# Imagem 52 achatada: (3969,)
# Imagem 53 achatada: (3969,)
# Imagem 54 achatada: (3969,)
# Imagem 55 achatada: (3969,)
# Imagem 56 achatada: (3969,)
# Imagem 57 achatada: (3969,)
# Imagem 58 achatada: (3969,)
# Imagem 59 achatada: (3969,)
# Imagem 60 achatada: (3969,)
# Imagem 61 achatada: (3969,)
# Imagem 62 achatada: (3969,)
# Imagem 63 achatada: (3969,)
# Imagem 64 achatada: (3969,)
# Imagem 65 achatada: (3969,)
# Imagem 66 achatada: (3969,)
# Imagem 67 achatada: (3969,)
# Imagem 68 achatada: (3969,)
# Imagem 69 achatada: (3969,)
# Imagem 70 achatada: (3969,)
# Imagem 71 achatada: (3969,)
# Imagem 72 achatada: (3969,)
# Imagem 73 achatada: (3969,)
# Imagem 74 achatada: (3969,)
# Imagem 75 achatada: (3969,)
# Imagem 76 achatada: (3969,)
# Imagem 77 achatada: (3969,)
# Imagem 78 achatada: (3969,)
# Imagem 79 achatada: (3969,)
# Imagem 80 achatada: (3969,)
# Imagem 81 achatada: (3969,)
# Imagem 82 achatada: (3969,)
# Imagem 83 achatada: (3969,)
# Imagem 84 achatada: (3969,)
# Imagem 85 achatada: (3969,)
# Imagem 86 achatada: (3969,)
# Imagem 87 achatada: (3969,)
# Imagem 88 achatada: (3969,)
# Imagem 89 achatada: (3969,)
# Imagem 90 achatada: (3969,)
# Imagem 91 achatada: (3969,)
# Imagem 92 achatada: (3969,)
# Imagem 93 achatada: (3969,)
# Imagem 94 achatada: (3969,)
# Imagem 95 achatada: (3969,)
# Imagem 96 achatada: (3969,)
# Imagem 97 achatada: (3969,)
# Imagem 98 achatada: (3969,)
# Imagem 99 achatada: (3969,)
# Imagem 100 achatada: (3969,)
# Imagem 101 achatada: (3969,)
# Imagem 102 achatada: (3969,)
# Imagem 103 achatada: (3969,)
# Imagem 104 achatada: (3969,)
# Imagem 105 achatada: (3969,)
# Imagem 106 achatada: (3969,)
# Imagem 107 achatada: (3969,)
# Imagem 108 achatada: (3969,)
# Imagem 109 achatada: (3969,)
# Imagem 110 achatada: (3969,)
# Imagem 111 achatada: (3969,)
# Imagem 112 achatada: (3969,)
# Imagem 113 achatada: (3969,)
# Imagem 114 achatada: (3969,)
# Imagem 115 achatada: (3969,)
# Imagem 116 achatada: (3969,)
# Imagem 117 achatada: (3969,)
# Imagem 118 achatada: (3969,)
# Imagem 119 achatada: (3969,)
# Imagem 120 achatada: (3969,)
# Imagem 121 achatada: (3969,)
# Imagem 122 achatada: (3969,)
# Imagem 123 achatada: (3969,)
# Imagem 124 achatada: (3969,)
# Imagem 125 achatada: (3969,)
# Imagem 126 achatada: (3969,)
# Imagem 127 achatada: (3969,)
# Imagem 128 achatada: (3969,)
# Imagem 129 achatada: (3969,)
# Imagem 130 achatada: (3969,)
# Imagem 131 achatada: (3969,)
# Imagem 132 achatada: (3969,)
# Imagem 133 achatada: (3969,)
# Imagem 134 achatada: (3969,)
# Imagem 135 achatada: (3969,)
# Imagem 136 achatada: (3969,)
# Imagem 137 achatada: (3969,)
# Imagem 138 achatada: (3969,)
# Imagem 139 achatada: (3969,)
# Imagem 140 achatada: (3969,)
# Imagem 141 achatada: (3969,)
# Imagem 142 achatada: (3969,)
# Imagem 143 achatada: (3969,)
# Imagem 144 achatada: (3969,)
# Imagem 145 achatada: (3969,)
# Imagem 146 achatada: (3969,)
# Imagem 147 achatada: (3969,)
# Imagem 148 achatada: (3969,)
# Imagem 149 achatada: (3969,)
# Imagem 150 achatada: (3969,)
# Imagem 151 achatada: (3969,)
# Imagem 152 achatada: (3969,)
# Imagem 153 achatada: (3969,)
# Imagem 154 achatada: (3969,)
# Imagem 155 achatada: (3969,)
# Imagem 156 achatada: (3969,)
# Imagem 157 achatada: (3969,)
# Imagem 158 achatada: (3969,)
# Imagem 159 achatada: (3969,)
# Imagem 160 achatada: (3969,)
# Imagem 161 achatada: (3969,)
# Imagem 162 achatada: (3969,)
# Imagem 163 achatada: (3969,)
# Imagem 164 achatada: (3969,)
# Imagem 165 achatada: (3969,)
# Imagem 166 achatada: (3969,)
# Imagem 167 achatada: (3969,)
# Imagem 168 achatada: (3969,)
# Imagem 169 achatada: (3969,)
# Imagem 170 achatada: (3969,)
# Imagem 171 achatada: (3969,)
# Imagem 172 achatada: (3969,)
# Imagem 173 achatada: (3969,)
# Imagem 174 achatada: (3969,)
# Imagem 175 achatada: (3969,)
# Imagem 176 achatada: (3969,)
# Imagem 177 achatada: (3969,)
# Imagem 178 achatada: (3969,)
# Imagem 179 achatada: (3969,)
# Imagem 180 achatada: (3969,)
# Imagem 181 achatada: (3969,)
# Imagem 182 achatada: (3969,)
# Imagem 183 achatada: (3969,)
# Imagem 184 achatada: (3969,)
# Imagem 185 achatada: (3969,)
# Imagem 186 achatada: (3969,)
# Imagem 187 achatada: (3969,)
# Imagem 188 achatada: (3969,)
# Imagem 189 achatada: (3969,)
# Imagem 190 achatada: (3969,)
# Imagem 191 achatada: (3969,)
# Imagem 192 achatada: (3969,)
# Imagem 193 achatada: (3969,)
# Imagem 194 achatada: (3969,)
# Imagem 195 achatada: (3969,)
# Imagem 196 achatada: (3969,)
# Imagem 197 achatada: (3969,)
# Imagem 198 achatada: (3969,)
# Imagem 199 achatada: (3969,)
# Imagem 200 achatada: (3969,)
# Imagem 201 achatada: (3969,)
# Imagem 202 achatada: (3969,)
# Imagem 203 achatada: (3969,)
# Imagem 204 achatada: (3969,)
# Imagem 205 achatada: (3969,)
# Imagem 206 achatada: (3969,)
# Imagem 207 achatada: (3969,)
# Imagem 208 achatada: (3969,)
# Imagem 209 achatada: (3969,)
# Imagem 210 achatada: (3969,)
# Imagem 211 achatada: (3969,)
# Imagem 212 achatada: (3969,)
# Imagem 213 achatada: (3969,)
# Imagem 214 achatada: (3969,)
# Imagem 215 achatada: (3969,)
# Imagem 216 achatada: (3969,)
# Imagem 217 achatada: (3969,)
# Imagem 218 achatada: (3969,)
# Imagem 219 achatada: (3969,)
# Imagem 220 achatada: (3969,)
# Imagem 221 achatada: (3969,)
# Imagem 222 achatada: (3969,)
# Imagem 223 achatada: (3969,)
# Imagem 224 achatada: (3969,)
# Imagem 225 achatada: (3969,)
# Imagem 226 achatada: (3969,)
# Imagem 227 achatada: (3969,)
# Imagem 228 achatada: (3969,)
# Imagem 229 achatada: (3969,)
# Imagem 230 achatada: (3969,)
# Imagem 231 achatada: (3969,)
# Imagem 232 achatada: (3969,)
# Imagem 233 achatada: (3969,)
# Imagem 234 achatada: (3969,)
# Imagem 235 achatada: (3969,)
# Imagem 236 achatada: (3969,)
# Imagem 237 achatada: (3969,)
# Imagem 238 achatada: (3969,)
# Imagem 239 achatada: (3969,)
# Imagem 240 achatada: (3969,)
# Imagem 241 achatada: (3969,)
# Imagem 242 achatada: (3969,)
# Imagem 243 achatada: (3969,)
# Imagem 244 achatada: (3969,)
# Imagem 245 achatada: (3969,)
# Imagem 246 achatada: (3969,)
# Imagem 247 achatada: (3969,)
# Imagem 248 achatada: (3969,)
# Imagem 249 achatada: (3969,)
# Imagem 250 achatada: (3969,)
# Imagem 251 achatada: (3969,)
# Imagem 252 achatada: (3969,)
# Imagem 253 achatada: (3969,)
# Imagem 254 achatada: (3969,)
# Imagem 255 achatada: (3969,)
# Imagem 256 achatada: (3969,)
# Imagem 257 achatada: (3969,)
# Imagem 258 achatada: (3969,)
# Imagem 259 achatada: (3969,)
# Imagem 260 achatada: (3969,)
# Imagem 261 achatada: (3969,)
# Imagem 262 achatada: (3969,)
# Imagem 263 achatada: (3969,)
# Imagem 264 achatada: (3969,)
# Imagem 265 achatada: (3969,)
# Imagem 266 achatada: (3969,)
# Imagem 267 achatada: (3969,)
# Imagem 268 achatada: (3969,)
# Imagem 269 achatada: (3969,)
# Imagem 270 achatada: (3969,)
# Imagem 271 achatada: (3969,)
# Imagem 272 achatada: (3969,)
# Imagem 273 achatada: (3969,)
# Imagem 274 achatada: (3969,)
# Imagem 275 achatada: (3969,)
# Imagem 276 achatada: (3969,)
# Imagem 277 achatada: (3969,)
# Imagem 278 achatada: (3969,)
# Imagem 279 achatada: (3969,)
# Imagem 280 achatada: (3969,)
# Imagem 281 achatada: (3969,)
# Imagem 282 achatada: (3969,)
# Imagem 283 achatada: (3969,)
# Imagem 284 achatada: (3969,)
# Imagem 285 achatada: (3969,)
# Imagem 286 achatada: (3969,)
# Imagem 287 achatada: (3969,)
# Imagem 288 achatada: (3969,)
# Imagem 289 achatada: (3969,)
# Imagem 290 achatada: (3969,)
# Imagem 291 achatada: (3969,)
# Imagem 292 achatada: (3969,)
# Imagem 293 achatada: (3969,)
# Imagem 294 achatada: (3969,)
# Imagem 295 achatada: (3969,)
# Imagem 296 achatada: (3969,)
# Imagem 297 achatada: (3969,)
# Imagem 298 achatada: (3969,)
# Imagem 299 achatada: (3969,)
# Total de imagens achatadas: 300

# %% [markdown]
# ### Etapa 4: Implementando a Rede Neural Fully Connected

# %%
import numpy as np
import os
from PIL import Image

# Função para inicializar os pesos e biases
def initialize_weights(input_size, hidden_size, output_size):
    np.random.seed(42)  # Para reprodutibilidade
    W1 = np.random.randn(input_size, hidden_size) * 0.01  # Pesos da camada oculta
    b1 = np.zeros((1, hidden_size))  # Bias da camada oculta
    W2 = np.random.randn(hidden_size, output_size) * 0.01  # Pesos da camada de saída
    b2 = np.zeros((1, output_size))  # Bias da camada de saída
    return W1, b1, W2, b2

# Função de ativação (ReLU)
def relu(z):
    return np.maximum(0, z)

# Função de ativação da camada de saída (Softmax)
def softmax(z):
    exp_z = np.exp(z - np.max(z))  # Para evitar overflow
    return exp_z / np.sum(exp_z, axis=1, keepdims=True)

# Forward Pass
def forward_pass(X, W1, b1, W2, b2):
    Z1 = np.dot(X, W1) + b1  # Camada oculta
    A1 = relu(Z1)            # Ativação ReLU
    Z2 = np.dot(A1, W2) + b2  # Camada de saída
    A2 = softmax(Z2)         # Ativação Softmax
    return A2, A1, Z1  # Retorna a saída da camada de saída e os valores intermediários

# Função para prever a classe
def predict(X, W1, b1, W2, b2):
    A2, _, _ = forward_pass(X, W1, b1, W2, b2)
    return np.argmax(A2, axis=1)

# Função de custo (Cross-Entropy)
def compute_loss(y_true, y_pred):
    m = y_true.shape[0]
    log_likelihood = -np.log(y_pred[range(m), y_true])
    return np.sum(log_likelihood) / m

# Função de treino
def train(X, y, W1, b1, W2, b2, epochs, learning_rate):
    for epoch in range(epochs):

        # Forward pass
        A2, A1, Z1 = forward_pass(X, W1, b1, W2, b2)

        # Cálculo da perda
        loss = compute_loss(y, A2)
        # Backward pass
        m = y.shape[0]
        dZ2 = A2.copy()
        dZ2[np.arange(m), np.argmax(y, axis=1)] -= 1  # Gradiente da perda
        dZ2 /= m
        
        dW2 = np.dot(A1.T, dZ2)  # Gradiente para W2
        db2 = np.sum(dZ2, axis=0, keepdims=True)  # Gradiente para b2
        
        dA1 = np.dot(dZ2, W2.T)  # Gradiente para A1
        dZ1 = dA1 * (Z1 > 0)  # Gradiente para Z1 usando ReLU
        
        dW1 = np.dot(X.T, dZ1)  # Gradiente para W1
        db1 = np.sum(dZ1, axis=0, keepdims=True)  # Gradiente para b1

        # Atualizando os pesos e biases
        W1 -= learning_rate * dW1
        b1 -= learning_rate * db1
        W2 -= learning_rate * dW2
        b2 -= learning_rate * db2

        if epoch % 100 == 0:  # Exibe a perda a cada 100 épocas
            print(f"Epoch {epoch}, Loss: {loss:.4f}")


# Função para carregar imagens e rótulos
def load_images(directory):
    images = []
    labels = []
    class_mapping = {
        'cow': 0,
        'bee': 1,
        'elephant': 2,
        'dog': 3,
        'cat': 4
    }
    
    for label, label_index in class_mapping.items():
        class_dir = os.path.join(directory, label)
        for filename in os.listdir(class_dir):
            if filename.endswith('.jpg') or filename.endswith('.png'):  # Adapte conforme o formato das suas imagens
                img_path = os.path.join(class_dir, filename)
                image = Image.open(img_path).resize((63, 63))  # Redimensionando para 63x63
                images.append(np.array(image).flatten())  # Achata a imagem
                labels.append(label_index)  # Adiciona o rótulo correspondente
    
    return np.array(images), np.array(labels)

# Definições de parâmetros
input_size = 63 * 63  # Tamanho de entrada (imagem achatada)
hidden_size = 128      # Número de neurônios na camada oculta
output_size = 5        # Número de classes (0 a 4, de acordo com o class_mapping)
epochs = 1000          # Número de épocas para o treinamento
learning_rate = 0.01   # Taxa de aprendizado

# Inicializando pesos e biases
W1, b1, W2, b2 = initialize_weights(input_size, hidden_size, output_size)


# Carregando as imagens e rótulos
testImgs, _ = load_images('testImgs')  # O diretório 'imgs' deve conter subpastas para cada classe

# Defina o mapeamento de rótulos para inteiros
class_mapping = {
    'elephant': 0,
    'bee': 1,
    'cat': 2,
    'dog': 3,
    'cow': 4
}

# Inicialize a matriz de one-hot encoding
num_classes = len(class_mapping)  # 5 classes no total (0 a 4)

# Mapear rótulos de strings para inteiros, apenas se estiverem no mapeamento
mapped_labels = np.array([class_mapping[label] for label in labelsFirst if label in class_mapping])


# Inicializando a matriz de one-hot encoding
y = np.zeros((mapped_labels.shape[0], num_classes))

print(mapped_labels.shape[0])

# Preencher a matriz de one-hot encoding com os valores mapeados
for idx, label in enumerate(mapped_labels):
    y[idx, label] = 1

flattened_images = np.array(flattened_images)

print("Dimensões de flattened_images:", flattened_images.shape)  # Exemplo: (300, 3969)
print("Dimensões de y:", y.shape)  # Exemplo: (300, 5)

# Treinando a rede neural
train(flattened_images, y, W1, b1, W2, b2, epochs, learning_rate)

# Forward pass para prever as classes
predictions = predict(testImgs, W1, b1, W2, b2)

# Imprimindo as previsões
print("Predições das classes:", predictions)
# Out:
# 300
# Dimensões de flattened_images: (300, 3969)
# Dimensões de y: (300, 5)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[318], line 144
#     141 print("Dimensões de y:", y.shape)  # Exemplo: (300, 5)
#     143 # Treinando a rede neural
# --> 144 train(flattened_images, y, W1, b1, W2, b2, epochs, learning_rate)
#     146 # Forward pass para prever as classes
#     147 predictions = predict(testImgs, W1, b1, W2, b2)
#
# Cell In[318], line 50, in train(X, y, W1, b1, W2, b2, epochs, learning_rate)
#      47 A2, A1, Z1 = forward_pass(X, W1, b1, W2, b2)
#      49 # Cálculo da perda
# ---> 50 loss = compute_loss(y, A2)
#      51 # Backward pass
#      52 m = y.shape[0]
#
# Cell In[318], line 39, in compute_loss(y_true, y_pred)
#      37 def compute_loss(y_true, y_pred):
#      38     m = y_true.shape[0]
# ---> 39     log_likelihood = -np.log(y_pred[range(m), y_true])
#      40     return np.sum(log_likelihood) / m
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
import numpy as np
from PIL import Image
import os

# Função para carregar as imagens de teste
def load_test_images(test_image_folder):
    test_images = []
    test_labels = []
    
    # Lendo cada subpasta que corresponde a uma classe
    for label, animal_folder in enumerate(os.listdir(test_image_folder)):
        animal_path = os.path.join(test_image_folder, animal_folder)
        
        # Certifique-se de que estamos lidando apenas com pastas
        if os.path.isdir(animal_path):
            for img_name in os.listdir(animal_path):
                if img_name.endswith('.jpg'):
                    img = Image.open(os.path.join(animal_path, img_name)).convert('L')
                    img = img.resize((128, 128))
                    test_images.append(np.array(img).flatten())
                    test_labels.append(label)

    return np.array(test_images), np.array(test_labels)

# Carregando imagens e rótulos de teste
test_images, test_labels = load_test_images('testImgs')

# Testando a rede neural
def test_network(model, test_images, test_labels):
    
    test_outputs = model.predict(test_images)  # Use o método apropriado para a sua rede neural

    predictions = np.argmax(test_outputs, axis=1)  # Índice da classe com maior probabilidade

    # Garantindo que predictions e test_labels tenham o mesmo tamanho
    if len(predictions) != len(test_labels):
        print(f"Erro: O número de previsões ({len(predictions)}) não corresponde ao número de rótulos ({len(test_labels)})")
        return

    accuracy = np.mean(predictions == test_labels)  # Cálculo da precisão
    test_loss = cross_entropy_loss(test_outputs, test_labels)  # Cálculo da perda
    print(f"Perda no teste: {test_loss:.4f}")
    print(f"Precisão no teste: {accuracy * 100:.2f}%")

    # Imprimindo previsões e classes reais
    for i in range(len(test_labels)):
        print(f"Imagem {i+1}: Previsão: {predictions[i]}, Classe Real: {test_labels[i]}")

# Criando a instância do modelo
input_size = 63 * 63 
hidden_size = 100  # Tamanho da camada oculta
output_size = 5  # Número de classes

model = SimpleNeuralNetwork(input_size, hidden_size, output_size)

# Testando a rede neural
test_network(model, test_images, test_labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[228], line 57
#      54 model = SimpleNeuralNetwork(input_size, hidden_size, output_size)
#      56 # Testando a rede neural
# ---> 57 test_network(model, test_images, test_labels)
#
# Cell In[228], line 31, in test_network(model, test_images, test_labels)
#      29 def test_network(model, test_images, test_labels):
# ---> 31     test_outputs = model.predict(test_images)  # Use o método apropriado para a sua rede neural
#      33     predictions = np.argmax(test_outputs, axis=1)  # Índice da classe com maior probabilidade
#      35     # Garantindo que predictions e test_labels tenham o mesmo tamanho
#
# Cell In[167], line 59, in SimpleNeuralNetwork.predict(self, X)
#      57 def predict(self, X):
#      58     # Realiza a passagem para frente e retorna as previsões
# ---> 59     output = self.forward(X)
#      60     return output
#
# Cell In[167], line 27, in SimpleNeuralNetwork.forward(self, X)
#      26 def forward(self, X):
# ---> 27     self.hidden_layer_activation = np.dot(X, self.weights_input_hidden) + self.bias_hidden
#      28     self.hidden_layer_output = relu(self.hidden_layer_activation)
#      29     self.output_layer_activation = np.dot(self.hidden_layer_output, self.weights_hidden_output) + self.bias_output
#
# ValueError: shapes (17,16384) and (3969,100) not aligned: 16384 (dim 1) != 3969 (dim 0)
